# %%
import bisect
import numpy
from numpy.linalg import norm
from numpy.linalg import svd 
from scipy.sparse.linalg import svds

# %%
def pcp_alm(X, maxiter=500, tol=1e-7):
    """Principal Component Pursuit
    Finds the Principal Component Pursuit solution.
    Solves the optimization problem::
        (L^*,S^*) = argmin || L ||_* + gamma * || S ||_1
                    (L,S)
                    subject to    L + S = X
    where || . ||_* is the nuclear norm.  Uses an augmented Lagrangian approach
    Parameters
    ----------
    X : array of shape [n_samples, n_features]
        Data matrix.
    maxiter : int, 500 by default
        Maximum number of iterations to perform.
    tol : float, 1e-7 by default - in the paper

    Returns
    -------
    L : array of shape [n_samples, n_features]
        The low rank component
    S : array of shape [n_samples, n_features]
        The sparse component
    (u, sig, vt) : tuple of arrays
        SVD of L.
    n_iter : int
        Number of iterations
    Reference
    ---------
       Candes, Li, Ma, and Wright
       Robust Principal Component Analysis?
       Submitted for publication, December 2009.
    """
    
    
    def soft_threshold(v = 0, tau = 0):
        '''
        shrinkiage opterator S_tau[x]
        '''
        tmp = numpy.abs(v)
        tmp = numpy.subtract(tmp, tau)
        tmp = numpy.maximum(tmp, 0.0)
        return numpy.multiply(numpy.sign(v), tmp)
    
    def svt(X, tau, k, svd_function, out=None):
        def svd_reconstruct(u, sig, v, out=None, tmp_out=None):
            tmp = np.multiply(u, sig, out=tmp_out)
            return np.dot(tmp, v, out=out)

        def truncate_top_k_svd(u, sig, v, k):
            return u[:, :k], sig[:k], v[:k, :]

        m, n = X.shape
        
        u, sig, v = svd_function(X, k)

        sig = soft_threshold(sig, tau)
        r = numpy.sum(sig > 0)
        
        u, sig, v = svd_function(X, r)
        sig = soft_threshold(sig, tau)

        if r > 0:
            print("Z= reconstructed")
            u, sig, v = truncate_top_k_svd(u, sig, v, r)
            print("reconstructed sig =", sig)
            Z = svd_reconstruct(u, sig, v, out=out)
        else:
            print("Z= 0")
            out[:] = 0
            Z = out
            u, sig, v = numpy.empty((m, 0)), numpy.empty((0, 0)), numpy.empty((0, n))
        return (Z, r, (u, sig, v))
    
    def svd_choice(n, d):
        '''
        choose svd depend on the size 

        return 'dense_top_k_svd/sparse_svds
        '''
    
        ratio = float(d) / float(n)
        vals = [(0, 0.02), (100, 0.06), (200, 0.26),
                (300, 0.28), (400, 0.34), (500, 0.38)]

        i = bisect.bisect_left([r[0] for r in vals], n)
        choice = dense_top_k_svd if ratio > vals[i-1][1] else svds
        return choice
    
    def dense_top_k_svd(A, k):
        '''
        A - matrix
        k - Top K components
        '''
        u, sig, v = svd(A, full_matrices=0)
        return u[:, :k], sig[:k], v[:k, :]
    
    n = X.shape
    frob_norm = numpy.linalg.norm(X, 'fro')
    two_norm = numpy.linalg.norm(X, 2)
    one_norm = numpy.sum(numpy.abs(X))
    inf_norm = numpy.max(numpy.abs(X))
    
    print("frob_norm", frob_norm)
    print("two_norm", two_norm)
    print("one_norm", one_norm)
    print("info_norm", inf_norm)

    mu_inv = 4 * one_norm / numpy.prod(n)
    
    gamma = 1/numpy.sqrt(numpy.max([X.shape[0], X.shape[1]]))
    print("gamma", gamma)
    # Kicking
    k = numpy.min([
        numpy.floor(mu_inv / two_norm),
        numpy.floor(gamma * mu_inv / inf_norm)
    ])
    Y = k * X
    sv = 10

    # Variable init
    S = numpy.zeros(n)
    
    print("k",k)
    print("mu_inv", mu_inv)
    
    for i in range(maxiter):
        
        # Shrink singular values
        l= X - S + mu_inv*Y
        svd_fun = svd_choice(numpy.min(l.shape), sv)
        print(svd_fun)
        print("sv", sv)
        L, r, (u, sig, v) = svt(l, mu_inv, sv, svd_function = svd_fun)
        print("non-zero sigular value", r)          
        if r < sv:
            sv = numpy.min([r + 1, numpy.min(n)])
        else:
            sv = numpy.min([r +  int(numpy.round(0.05 * numpy.min(n))), numpy.min(n)])
        
        # Shrink entries
        s = X - L + mu_inv*Y
        S = soft_threshold(s, gamma * mu_inv)
    
        # Check convergence
        R= X - L - S
        stopCriterion = numpy.linalg.norm(R, 'fro') / frob_norm
        print("stopCriterion", stopCriterion)
        if stopCriterion < tol:
            break

        # Update dual variable
        Y += 1/mu_inv *(X - L - S) 

    return L, S, (u, sig, v), i + 1

# %%
###test###

import numpy as np

n = 100
r = 3
np.random.seed(123)
base = 100 + np.cumsum(np.random.randn(n, r), axis=0)
scales = np.abs(np.random.randn(n, r))
L = np.dot(base, scales.T)
S = np.round(0.25 * np.random.randn(n, n))
M = L + S

L_hat, S_hat, r, niter = pcp_alm(M,500)
print(np.max(np.abs(S - S_hat)))
print(np.max(np.abs(L - L_hat)))
print(niter)



_, s, _ = np.linalg.svd(L, full_matrices=False)
print (s[s > 1e-11])

_, s_hat, _ = np.linalg.svd(L_hat, full_matrices=False)
print (s_hat[s_hat > 1e-11])
# Out:
# frob_norm 25592.2494664
# two_norm 25589.5984847
# one_norm 2355268.6747
# info_norm 526.610206522
# gamma 0.1
# k 0.0
# mu_inv 942.107469879
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 10
# Z= reconstructed
# reconstructed sig = [ 24647.4910148]
# non-zero sigular value 1
# stopCriterion 0.0395259325301
# <function svds at 0x10ed25048>
# sv 2
# Z= reconstructed
# reconstructed sig = [ 25589.59848468]
# non-zero sigular value 1
# stopCriterion 0.014393051743
# <function svds at 0x10ed25048>
# sv 2
# Z= reconstructed
# reconstructed sig = [    80.91406357  25589.59848468]
# non-zero sigular value 2
# stopCriterion 0.0115282303434
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 7
# Z= reconstructed
# reconstructed sig = [ 25589.59848468    341.00717782]
# non-zero sigular value 2
# stopCriterion 0.00544189803452
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 3
# Z= reconstructed
# reconstructed sig = [ 25589.59848468    341.00717782]
# non-zero sigular value 2
# stopCriterion 0.00544189803452
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 3
# Z= reconstructed
# reconstructed sig = [ 25589.59848468    341.00717782]
# non-zero sigular value 2
# stopCriterion 0.00544189803452
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 3
# Z= reconstructed
# reconstructed sig = [  2.55895985e+04   3.41007178e+02   2.24085200e+01]
# non-zero sigular value 3
# stopCriterion 0.00456060683907
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 8
# Z= reconstructed
# reconstructed sig = [ 25589.255833      340.88741312    136.27503931]
# non-zero sigular value 3
# stopCriterion 0.000804737095525
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.69267237    341.03980002    138.19650349]
# non-zero sigular value 3
# stopCriterion 0.000792599689164
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.60680769    341.0100287     137.82356763]
# non-zero sigular value 3
# stopCriterion 0.000791229387947
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57830354    340.99996586    137.69812671]
# non-zero sigular value 3
# stopCriterion 0.000791107501187
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57811772    340.99990175    137.69730765]
# non-zero sigular value 3
# stopCriterion 0.00079110626509
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57947277    341.00038373    137.70328677]
# non-zero sigular value 3
# stopCriterion 0.000791104493448
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57974331    341.00048069    137.70448306]
# non-zero sigular value 3
# stopCriterion 0.000791103386462
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57977316    341.00049182    137.70461704]
# non-zero sigular value 3
# stopCriterion 0.000791102621806
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57981002    341.00050521    137.7047815 ]
# non-zero sigular value 3
# stopCriterion 0.000791102072524
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57985304    341.00052067    137.70497285]
# non-zero sigular value 3
# stopCriterion 0.000791101665318
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57989165    341.00053449    137.70514444]
# non-zero sigular value 3
# stopCriterion 0.00079110135727
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57992505    341.00054642    137.70529287]
# non-zero sigular value 3
# stopCriterion 0.000791101120857
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57995424    341.00055683    137.70542254]
# non-zero sigular value 3
# stopCriterion 0.000791100937464
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.57997991    341.00056598    137.70553654]
# non-zero sigular value 3
# stopCriterion 0.000791100794085
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58000255    341.00057404    137.70563703]
# non-zero sigular value 3
# stopCriterion 0.000791100681367
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58002255    341.00058116    137.70572575]
# non-zero sigular value 3
# stopCriterion 0.000791100592407
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58004024    341.00058746    137.70580423]
# non-zero sigular value 3
# stopCriterion 0.000791100522007
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58005591    341.00059304    137.70587375]
# non-zero sigular value 3
# stopCriterion 0.000791100466188
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58006982    341.00059799    137.70593539]
# non-zero sigular value 3
# stopCriterion 0.000791100421872
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58008216    341.00060238    137.70599012]
# non-zero sigular value 3
# stopCriterion 0.000791100386656
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58009313    341.00060628    137.70603873]
# non-zero sigular value 3
# stopCriterion 0.000791100358653
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58010289    341.00060976    137.70608196]
# non-zero sigular value 3
# stopCriterion 0.000791100336376
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58011157    341.00061284    137.70612041]
# non-zero sigular value 3
# stopCriterion 0.000791100318647
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.5801193     341.00061559    137.70615463]
# non-zero sigular value 3
# stopCriterion 0.000791100304535
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58012618    341.00061804    137.7061851 ]
# non-zero sigular value 3
# stopCriterion 0.000791100293299
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58013231    341.00062022    137.70621224]
# non-zero sigular value 3
# stopCriterion 0.000791100284352
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58013777    341.00062216    137.70623642]
# non-zero sigular value 3
# stopCriterion 0.000791100277226
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58014264    341.0006239     137.70625797]
# non-zero sigular value 3
# stopCriterion 0.00079110027155
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58014697    341.00062544    137.70627717]
# non-zero sigular value 3
# stopCriterion 0.000791100267029
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58015084    341.00062682    137.70629429]
# non-zero sigular value 3
# stopCriterion 0.000791100263426
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58015429    341.00062804    137.70630955]
# non-zero sigular value 3
# stopCriterion 0.000791100260555
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58015737    341.00062914    137.70632316]
# non-zero sigular value 3
# stopCriterion 0.000791100258267
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58016011    341.00063011    137.7063353 ]
# non-zero sigular value 3
# stopCriterion 0.000791100256444
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58016256    341.00063098    137.70634613]
# non-zero sigular value 3
# stopCriterion 0.00079110025499
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58016474    341.00063176    137.70635578]
# non-zero sigular value 3
# stopCriterion 0.000791100253831
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58016668    341.00063245    137.70636439]
# non-zero sigular value 3
# stopCriterion 0.000791100252906
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58016842    341.00063307    137.70637208]
# non-zero sigular value 3
# stopCriterion 0.000791100252169
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58016997    341.00063362    137.70637893]
# non-zero sigular value 3
# stopCriterion 0.000791100251581
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58017135    341.00063411    137.70638505]
# non-zero sigular value 3
# stopCriterion 0.000791100251112
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58017259    341.00063455    137.7063905 ]
# non-zero sigular value 3
# stopCriterion 0.000791100250737
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58017369    341.00063494    137.70639537]
# non-zero sigular value 3
# stopCriterion 0.000791100250438
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58017467    341.00063529    137.70639972]
# non-zero sigular value 3
# stopCriterion 0.0007911002502
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.58017555    341.00063561    137.70640359]
# non-zero sigular value 3
# stopCriterion 0.000790363080132
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.55858496    341.00811686    137.65485012]
# non-zero sigular value 3
# stopCriterion 0.000790221115514
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.55717898    341.00854985    137.65140633]
# non-zero sigular value 3
# stopCriterion 0.0007902023292
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.56259718    341.00671896    137.66450161]
# non-zero sigular value 3
# stopCriterion 0.000790187942189
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.56313269    341.0065727     137.66591559]
# non-zero sigular value 3
# stopCriterion 0.00079018105039
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.56287853    341.00666022    137.66532824]
# non-zero sigular value 3
# stopCriterion 0.000790048645266
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.56107537    341.00667966    137.65939145]
# non-zero sigular value 3
# stopCriterion 0.000788931607633
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.52212473    340.99696132    137.56098189]
# non-zero sigular value 3
# stopCriterion 0.000788846874093
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.53394244    340.99902544    137.59283697]
# non-zero sigular value 3
# stopCriterion 0.000788801556104
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.53786726    341.00035669    137.60244084]
# non-zero sigular value 3
# stopCriterion 0.000788783453687
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.53773055    341.00039272    137.60216431]
# non-zero sigular value 3
# stopCriterion 0.000788770775484
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.53730064    341.00028027    137.60112044]
# non-zero sigular value 3
# stopCriterion 0.000788760905526
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.53704482    341.00021701    137.60052741]
# non-zero sigular value 3
# stopCriterion 0.000788315616464
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.53054345    340.97712457    137.60070564]
# non-zero sigular value 3
# stopCriterion 0.000787131367746
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.50545172    340.90779034    137.58699244]
# non-zero sigular value 3
# stopCriterion 0.000786562243886
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.50081666    340.92199927    137.54773873]
# non-zero sigular value 3
# stopCriterion 0.000785602046577
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.49129363    340.91128721    137.55974315]
# non-zero sigular value 3
# stopCriterion 0.000784811386547
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.46408865    340.87433962    137.55778365]
# non-zero sigular value 3
# stopCriterion 0.000783506238334
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.45834652    340.88354429    137.52840017]
# non-zero sigular value 3
# stopCriterion 0.000781724926451
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.4048887     340.869139      137.51704961]
# non-zero sigular value 3
# stopCriterion 0.000779126314705
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.3807142     340.83612475    137.49560333]
# non-zero sigular value 3
# stopCriterion 0.000776023171871
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.34360488    340.81494075    137.44200821]
# non-zero sigular value 3
# stopCriterion 0.000774488984156
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.33945796    340.77826941    137.46324708]
# non-zero sigular value 3
# stopCriterion 0.000769359904486
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.26444778    340.74177788    137.36450029]
# non-zero sigular value 3
# stopCriterion 0.000762356996271
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.1502488     340.69198309    137.25334733]
# non-zero sigular value 3
# stopCriterion 0.000759632303656
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.13614881    340.69407195    137.27502294]
# non-zero sigular value 3
# stopCriterion 0.000758517739534
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.16207056    340.69850022    137.29383263]
# non-zero sigular value 3
# stopCriterion 0.000754677118689
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.08594724    340.6665815     137.25500715]
# non-zero sigular value 3
# stopCriterion 0.000751262994439
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.05390471    340.60663373    137.23275135]
# non-zero sigular value 3
# stopCriterion 0.000746211251544
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.98986919    340.61582083    137.17360767]
# non-zero sigular value 3
# stopCriterion 0.000740896670093
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.93571524    340.53690358    137.17980027]
# non-zero sigular value 3
# stopCriterion 0.00073721268059
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.9028443     340.52731343    137.146052  ]
# non-zero sigular value 3
# stopCriterion 0.000735412448854
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.91063056    340.52566016    137.15660389]
# non-zero sigular value 3
# stopCriterion 0.000731718246318
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.8597104     340.49946405    137.15958892]
# non-zero sigular value 3
# stopCriterion 0.000726262252909
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.82590011    340.48516351    137.10513617]
# non-zero sigular value 3
# stopCriterion 0.000721019336208
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.75673634    340.44905117    137.11875222]
# non-zero sigular value 3
# stopCriterion 0.000712377645099
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.711584      340.39063244    137.09102848]
# non-zero sigular value 3
# stopCriterion 0.000701183045273
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.61853698    340.3356733     137.00607336]
# non-zero sigular value 3
# stopCriterion 0.000693018574094
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.62423291    340.32110047    136.99530825]
# non-zero sigular value 3
# stopCriterion 0.000683402062226
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.57268122    340.2985851     136.98910489]
# non-zero sigular value 3
# stopCriterion 0.000678110382291
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.52323011    340.31397591    137.0072935 ]
# non-zero sigular value 3
# stopCriterion 0.000671441142499
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.48836774    340.3016054     136.98718052]
# non-zero sigular value 3
# stopCriterion 0.000662609639725
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.49551739    340.25717845    136.91609769]
# non-zero sigular value 3
# stopCriterion 0.000648849163741
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.42528249    340.20285046    136.89151918]
# non-zero sigular value 3
# stopCriterion 0.000633713149881
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.35505379    340.18115764    136.92908791]
# non-zero sigular value 3
# stopCriterion 0.000619165561182
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.33596895    340.16110009    136.92291275]
# non-zero sigular value 3
# stopCriterion 0.000606294663953
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.28179145    340.18997962    136.90239795]
# non-zero sigular value 3
# stopCriterion 0.000590950971745
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.27325583    340.20834059    136.89166547]
# non-zero sigular value 3
# stopCriterion 0.000568463467662
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.19049882    340.21953846    136.87281701]
# non-zero sigular value 3
# stopCriterion 0.000554436972638
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.28518275    340.15147265    136.84199905]
# non-zero sigular value 3
# stopCriterion 0.000539559305872
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.22383158    340.17024202    136.89564357]
# non-zero sigular value 3
# stopCriterion 0.000521610765473
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.2025694     340.17634974    136.94995987]
# non-zero sigular value 3
# stopCriterion 0.000500389339575
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.21760428    340.16504556    136.96878141]
# non-zero sigular value 3
# stopCriterion 0.000487629442805
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.24453257    340.14403505    136.9543161 ]
# non-zero sigular value 3
# stopCriterion 0.000475078101172
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.30192627    340.13891056    136.90022715]
# non-zero sigular value 3
# stopCriterion 0.00046284143154
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.32824283    340.06952945    136.93649628]
# non-zero sigular value 3
# stopCriterion 0.000444422596564
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.34901901    340.11523547    136.93650181]
# non-zero sigular value 3
# stopCriterion 0.000430967127634
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.36572904    340.14442513    136.96298429]
# non-zero sigular value 3
# stopCriterion 0.000418857800575
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.38634837    340.14943007    136.98660731]
# non-zero sigular value 3
# stopCriterion 0.000405310465129
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.40659279    340.15075258    137.00422814]
# non-zero sigular value 3
# stopCriterion 0.000393138978487
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.41870882    340.13832847    137.06203601]
# non-zero sigular value 3
# stopCriterion 0.00038109177743
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.43729215    340.13523104    137.12501792]
# non-zero sigular value 3
# stopCriterion 0.000365156347014
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.54133543    340.13668905    137.12021379]
# non-zero sigular value 3
# stopCriterion 0.000346776723098
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.63161798    340.15155016    137.1531975 ]
# non-zero sigular value 3
# stopCriterion 0.000329807879752
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.63837915    340.16421021    137.21986889]
# non-zero sigular value 3
# stopCriterion 0.000319069245512
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.61370429    340.17511453    137.26982614]
# non-zero sigular value 3
# stopCriterion 0.000302017548803
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.70895274    340.17239209    137.29147187]
# non-zero sigular value 3
# stopCriterion 0.000293125889201
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.7369111     340.18998186    137.27303439]
# non-zero sigular value 3
# stopCriterion 0.000280678285613
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.81185653    340.15807141    137.31477483]
# non-zero sigular value 3
# stopCriterion 0.000274731234752
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.77702854    340.1910086     137.32056992]
# non-zero sigular value 3
# stopCriterion 0.000260745278275
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.79067856    340.26999296    137.40511442]
# non-zero sigular value 3
# stopCriterion 0.000253376259071
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.8221127     340.2331173     137.41314501]
# non-zero sigular value 3
# stopCriterion 0.000230778607162
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.87940361    340.36324205    137.44999011]
# non-zero sigular value 3
# stopCriterion 0.000221420660127
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.90283302    340.34318876    137.47122898]
# non-zero sigular value 3
# stopCriterion 0.000212666071303
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.88977822    340.37949821    137.47233774]
# non-zero sigular value 3
# stopCriterion 0.000209865624786
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.89268121    340.37390853    137.46535522]
# non-zero sigular value 3
# stopCriterion 0.000203815045004
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.92619346    340.36492134    137.48970314]
# non-zero sigular value 3
# stopCriterion 0.000199725596866
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.94453275    340.37018361    137.49388026]
# non-zero sigular value 3
# stopCriterion 0.000189060633227
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.93340181    340.4246297     137.52036515]
# non-zero sigular value 3
# stopCriterion 0.000178563910915
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.95829259    340.4489943     137.58116848]
# non-zero sigular value 3
# stopCriterion 0.000171966222895
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.97289716    340.46811046    137.55883392]
# non-zero sigular value 3
# stopCriterion 0.000162998533497
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25588.99839662    340.48060163    137.5654974 ]
# non-zero sigular value 3
# stopCriterion 0.000154129156345
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.03460982    340.46541521    137.60332682]
# non-zero sigular value 3
# stopCriterion 0.00015232004603
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.02125452    340.46395639    137.59599379]
# non-zero sigular value 3
# stopCriterion 0.000148478589632
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.02382574    340.50619726    137.58804136]
# non-zero sigular value 3
# stopCriterion 0.000134475242808
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.06352998    340.58709687    137.59841314]
# non-zero sigular value 3
# stopCriterion 0.000125695306958
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.08472771    340.56639748    137.62228354]
# non-zero sigular value 3
# stopCriterion 0.000117532024458
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.11577627    340.57503395    137.64352973]
# non-zero sigular value 3
# stopCriterion 0.000116859081082
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.09514308    340.56527914    137.62963095]
# non-zero sigular value 3
# stopCriterion 0.000114086056973
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.0969917     340.56810459    137.63113121]
# non-zero sigular value 3
# stopCriterion 0.000105410049081
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.12333995    340.60452677    137.64365388]
# non-zero sigular value 3
# stopCriterion 0.00010418075739
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.12094248    340.60451847    137.63963828]
# non-zero sigular value 3
# stopCriterion 0.000103833342827
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.11555658    340.59731592    137.63854904]
# non-zero sigular value 3
# stopCriterion 9.86471749073e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.09263754    340.60358654    137.68872891]
# non-zero sigular value 3
# stopCriterion 9.77187939482e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.09192099    340.60447369    137.68533666]
# non-zero sigular value 3
# stopCriterion 7.83681774354e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.14837917    340.60962401    137.75722545]
# non-zero sigular value 3
# stopCriterion 6.64012976903e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.17416092    340.59473232    137.80117843]
# non-zero sigular value 3
# stopCriterion 6.53671366233e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.15621956    340.5961237     137.76850951]
# non-zero sigular value 3
# stopCriterion 6.46979478704e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.15174076    340.59961647    137.76093201]
# non-zero sigular value 3
# stopCriterion 6.43896511986e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.15227895    340.60013075    137.76236372]
# non-zero sigular value 3
# stopCriterion 6.41652507327e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.15303783    340.59994619    137.76374221]
# non-zero sigular value 3
# stopCriterion 6.39898179395e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.15345723    340.5999268     137.76440085]
# non-zero sigular value 3
# stopCriterion 6.38522644661e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.15373203    340.60000742    137.76483363]
# non-zero sigular value 3
# stopCriterion 5.61566256261e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.1648787     340.62801804    137.76391883]
# non-zero sigular value 3
# stopCriterion 4.85576026571e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.17336633    340.64840907    137.76604484]
# non-zero sigular value 3
# stopCriterion 3.89916035261e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.18386859    340.66326888    137.77467662]
# non-zero sigular value 3
# stopCriterion 3.80825062644e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.17766253    340.65173928    137.77125337]
# non-zero sigular value 3
# stopCriterion 3.75173722171e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.17671078    340.64878043    137.7710344 ]
# non-zero sigular value 3
# stopCriterion 3.72731348925e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.17707811    340.64926481    137.77136662]
# non-zero sigular value 3
# stopCriterion 3.71096504286e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.17736827    340.64974756    137.77159484]
# non-zero sigular value 3
# stopCriterion 1.83168886378e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19870965    340.65689467    137.80417226]
# non-zero sigular value 3
# stopCriterion 1.10244006521e-05
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.202152      340.65738991    137.81321736]
# non-zero sigular value 3
# stopCriterion 9.77441429103e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19659145    340.65569503    137.80410418]
# non-zero sigular value 3
# stopCriterion 8.3485338412e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19562715    340.65571527    137.80109703]
# non-zero sigular value 3
# stopCriterion 7.50694836213e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19602944    340.65587375    137.80185054]
# non-zero sigular value 3
# stopCriterion 6.76852825858e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19638296    340.65595966    137.80268825]
# non-zero sigular value 3
# stopCriterion 6.10766887741e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19659426    340.65602743    137.80311771]
# non-zero sigular value 3
# stopCriterion 5.51841015757e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19675425    340.65609091    137.80340979]
# non-zero sigular value 3
# stopCriterion 4.99174068414e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19689869    340.65614665    137.80368347]
# non-zero sigular value 3
# stopCriterion 4.51951698234e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19703128    340.65619423    137.80394415]
# non-zero sigular value 3
# stopCriterion 4.09504291848e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19715082    340.6562353     137.80418336]
# non-zero sigular value 3
# stopCriterion 3.71278343659e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19725776    340.65627121    137.80440023]
# non-zero sigular value 3
# stopCriterion 3.36804008779e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19735355    340.6563028     137.80459717]
# non-zero sigular value 3
# stopCriterion 3.05675987446e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19743956    340.65633068    137.80477649]
# non-zero sigular value 3
# stopCriterion 2.77541508104e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19751692    340.65635538    137.80493996]
# non-zero sigular value 3
# stopCriterion 2.52091419807e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19758658    340.65637734    137.80508906]
# non-zero sigular value 3
# stopCriterion 2.29053212745e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19764935    340.65639692    137.80522508]
# non-zero sigular value 3
# stopCriterion 2.08185505972e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19770596    340.65641445    137.80534924]
# non-zero sigular value 3
# stopCriterion 1.89273650356e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19775704    340.65643018    137.80546261]
# non-zero sigular value 3
# stopCriterion 1.72126163554e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19780317    340.65644433    137.80556617]
# non-zero sigular value 3
# stopCriterion 1.56571790734e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19784485    340.65645709    137.80566079]
# non-zero sigular value 3
# stopCriterion 1.42457045682e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19788253    340.65646862    137.80574726]
# non-zero sigular value 3
# stopCriterion 1.29644128396e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19791661    340.65647905    137.8058263 ]
# non-zero sigular value 3
# stopCriterion 1.18009143076e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19794745    340.65648851    137.80589857]
# non-zero sigular value 3
# stopCriterion 1.07440559641e-06
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19797536    340.6564971     137.80596466]
# non-zero sigular value 3
# stopCriterion 9.78378756328e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19800064    340.65650491    137.80602511]
# non-zero sigular value 3
# stopCriterion 8.91104452005e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19802355    340.65651202    137.80608041]
# non-zero sigular value 3
# stopCriterion 8.11764490568e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.1980443     340.6565185     137.80613099]
# non-zero sigular value 3
# stopCriterion 7.3961984595e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19806312    340.6565244     137.80617728]
# non-zero sigular value 3
# stopCriterion 6.74002593268e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19808018    340.65652979    137.80621964]
# non-zero sigular value 3
# stopCriterion 6.14308738241e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19809565    340.65653471    137.8062584 ]
# non-zero sigular value 3
# stopCriterion 5.59991826768e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19810969    340.65653921    137.80629388]
# non-zero sigular value 3
# stopCriterion 5.10557238221e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19812243    340.65654332    137.80632635]
# non-zero sigular value 3
# stopCriterion 4.65557080362e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.198134      340.65654708    137.80635608]
# non-zero sigular value 3
# stopCriterion 4.24585615879e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.1981445     340.65655051    137.80638329]
# non-zero sigular value 3
# stopCriterion 3.87275159848e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19815403    340.65655366    137.80640821]
# non-zero sigular value 3
# stopCriterion 3.53292395673e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19816269    340.65655654    137.80643102]
# non-zero sigular value 3
# stopCriterion 3.22335063576e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19817056    340.65655918    137.8064519 ]
# non-zero sigular value 3
# stopCriterion 2.94128981447e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19817771    340.6565616     137.80647103]
# non-zero sigular value 3
# stopCriterion 2.68425362618e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.1981842     340.65656381    137.80648854]
# non-zero sigular value 3
# stopCriterion 2.44998399387e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19819011    340.65656584    137.80650457]
# non-zero sigular value 3
# stopCriterion 2.23643084474e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19819548    340.6565677     137.80651926]
# non-zero sigular value 3
# stopCriterion 2.04173245995e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19820036    340.65656941    137.80653271]
# non-zero sigular value 3
# stopCriterion 1.8641977396e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.1982048     340.65657097    137.80654502]
# non-zero sigular value 3
# stopCriterion 1.70229018965e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19820884    340.6565724     137.8065563 ]
# non-zero sigular value 3
# stopCriterion 1.55461345588e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19821252    340.65657371    137.80656663]
# non-zero sigular value 3
# stopCriterion 1.41989825026e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19821586    340.65657492    137.8065761 ]
# non-zero sigular value 3
# stopCriterion 1.29699053098e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.1982189     340.65657602    137.80658476]
# non-zero sigular value 3
# stopCriterion 1.18484081164e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19822167    340.65657703    137.8065927 ]
# non-zero sigular value 3
# stopCriterion 1.08249448779e-07
# <function pcp_alm.<locals>.dense_top_k_svd at 0x10f467d90>
# sv 4
# Z= reconstructed
# reconstructed sig = [ 25589.19822419    340.65657796    137.80659998]
# non-zero sigular value 3
# stopCriterion 9.89083081537e-08
# 0.000549386592638
# 0.000549386592638
# 209
# [ 25589.19825013    340.65658823    137.8066795 ]
# [ 25589.19822419    340.65657796    137.80659998]

# %% [markdown]
# #### Reference
# Code Reference: https://github.com/apapanico/sklearn-rpca/blob/master/sklearnrpca/rpca_alm.py
# Modified based on the alternativate direction algorithm presented in the original paper: https://statweb.stanford.edu/~candes/papers/RobustPCA.pdf
